# %%
# load save/label_trainingweight_results.pkl

import pickle
import numpy as np
import matplotlib.pyplot as plt

# use seaborn
import seaborn as sns
sns.set()

# %%
def plot_results(resultsfile):

    with open(resultsfile, 'rb') as f:
        results = pickle.load(f)

    for i, result in enumerate(results):
        # order result based on the value of the first index in each tuple
        result = sorted(result, key=lambda x: x[0])
        # remove all tuples that are (0, 0)
        result = [x for x in result if x != (0, 0)]
        print(result)
        # result is a list of tuples of (x,y) values, plot these as points
        x, y = zip(*result)
        plt.plot(x, y, marker='x', linestyle='-')
        # add title and axis labels
        plt.title('Validation accuracy vs Tau: ' + resultsfile)
        plt.xlabel('Tau')
        plt.ylabel('Average validation accuracy')
        # add legend
        plt.legend(['invloss', 'l2', 'cosine', 'origin'])
        # add
    plt.show()

# %%
resultsfiles = ['label_trainingweight_results.pkl', 'fivecluster_trainingweight_results.pkl', 'fivecluster_priorweight_results.pkl', 'label_priorweight_results.pkl']

for resultsfile in resultsfiles:
    plot_results(resultsfile)
# Out:
# [(1.0, 66.58), (5.0, 69.21), (10.0, 70.43), (30.0, 68.05)]
# [(1.0, 67.71), (10.0, 68.49), (30.0, 69.33), (80.0, 68.64), (200.0, 68.26)]
# [(1.0, 67.19), (10.0, 65.5), (30.0, 58.87), (80.0, 62.53), (200.0, 68.0)]
# [(1.0, 67.88), (10.0, 67.54), (30.0, 67.77), (80.0, 68.47), (200.0, 69.21)]
# [(1.0, 86.87), (5.0, 89.3), (10.0, 87.1), (30.0, 86.29)]
# [(1.0, 86.89), (10.0, 87.3), (30.0, 88.81), (80.0, 88.62), (200.0, 87.66)]
# [(30.0, 85.96), (80.0, 88.62), (200.0, 89.82)]
# [(10.0, 86.74), (30.0, 87.14), (80.0, 86.96), (200.0, 87.52)]
# [(5.0, 90.78), (10.0, 90.4), (30.0, 90.47)]
# [(30.0, 88.59), (80.0, 87.99), (200.0, 87.4)]
# [(30.0, 86.01), (80.0, 89.85)]
# [(30.0, 87.87), (80.0, 88.04)]
# [(5.0, 69.23), (10.0, 68.42), (30.0, 66.78)]
# [(30.0, 67.65), (80.0, 62.55), (200.0, 62.29)]
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 resultsfiles = ['label_trainingweight_results.pkl', 'fivecluster_trainingweight_results.pkl', 'fivecluster_priorweight_results.pkl', 'label_priorweight_results.pkl']
#       3 for resultsfile in resultsfiles:
# ----> 4     plot_results(resultsfile)
#
# Cell In[2], line 13, in plot_results(resultsfile)
#      11 print(result)
#      12 # result is a list of tuples of (x,y) values, plot these as points
# ---> 13 x, y = zip(*result)
#      14 plt.plot(x, y, marker='x', linestyle='-')
#      15 # add title and axis labels
#
# ValueError: not enough values to unpack (expected 2, got 0)
